# %% [markdown]
# ## Evaluation of the datasets with CICFlowmeter

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir=root_dir+'proyecto_grado_redes/evaluation_datasets/'
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %% [markdown]
# ## Reading the dataset

# %%
df_cic_normal1_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_1_pcap_Flow.csv")
df_cic_normal1_org['Label'] = df_cic_normal1_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_normal2_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_2_pcap_Flow.csv")
df_cic_normal2_org['Label'] = df_cic_normal2_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_normal3_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_heavy_1_pcap_Flow.csv")
df_cic_normal3_org['Label'] = df_cic_normal3_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_normal4_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_heavy_2_pcap_Flow.csv")
df_cic_normal4_org['Label'] = df_cic_normal4_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_normal5_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_heavy_3_pcap_Flow.csv")
df_cic_normal5_org['Label'] = df_cic_normal5_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_normal6_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_benign_light_1_pcap_Flow.csv")
df_cic_normal6_org['Label'] = df_cic_normal6_org['Label'].map({'NeedManualLabel': 'Normal'})

# %%
df_cic_attack1_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_audio_pcap_Flow.csv")
df_cic_attack1_org['Label'] = df_cic_attack1_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack2_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_compressed_pcap_Flow.csv")
df_cic_attack2_org['Label'] = df_cic_attack2_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack3_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_exe_pcap_Flow.csv")
df_cic_attack3_org['Label'] = df_cic_attack3_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack4_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_image_pcap_Flow.csv")
df_cic_attack4_org['Label'] = df_cic_attack4_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack5_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_text_pcap_Flow.csv")
df_cic_attack5_org['Label'] = df_cic_attack5_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack6_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_heavy_video_pcap_Flow.csv")
df_cic_attack6_org['Label'] = df_cic_attack6_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack7_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_audio_pcap_Flow.csv")
df_cic_attack7_org['Label'] = df_cic_attack7_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack8_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_compressed_pcap_Flow.csv")
df_cic_attack8_org['Label'] = df_cic_attack8_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack9_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_exe_pcap_Flow.csv")
df_cic_attack9_org['Label'] = df_cic_attack9_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack10_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_image_pcap_Flow.csv")
df_cic_attack10_org['Label'] = df_cic_attack10_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack11_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_text_pcap_Flow.csv")
df_cic_attack11_org['Label'] = df_cic_attack11_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_attack12_org=pd.read_csv(base_dir+"csv_original/CICBellEXFDNS2021_light_video_pcap_Flow.csv")
df_cic_attack12_org['Label'] = df_cic_attack12_org['Label'].map({'NeedManualLabel': 'Attack'})

# %%
df_cic_normal1_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_1_pcap_Flow.csv")
df_cic_normal1_srg['Label'] = df_cic_normal1_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_normal2_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_2_pcap_Flow.csv")
df_cic_normal2_srg['Label'] = df_cic_normal2_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_normal3_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_heavy_1_pcap_Flow.csv")
df_cic_normal3_srg['Label'] = df_cic_normal3_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_normal4_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_heavy_2_pcap_Flow.csv")
df_cic_normal4_srg['Label'] = df_cic_normal4_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_normal5_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_heavy_3_pcap_Flow.csv")
df_cic_normal5_srg['Label'] = df_cic_normal5_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_normal6_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_benign_light_1_pcap_Flow.csv")
df_cic_normal6_srg['Label'] = df_cic_normal6_srg['Label'].map({'ManualLabel': 'Normal'})

# %%
df_cic_attack1_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_audio_pcap_Flow.csv")
df_cic_attack1_srg['Label'] = df_cic_attack1_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack2_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_compressed_pcap_Flow.csv")
df_cic_attack2_srg['Label'] = df_cic_attack2_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack3_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_exe_pcap_Flow.csv")
df_cic_attack3_srg['Label'] = df_cic_attack3_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack4_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_image_pcap_Flow.csv")
df_cic_attack4_srg['Label'] = df_cic_attack4_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack5_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_text_pcap_Flow.csv")
df_cic_attack5_srg['Label'] = df_cic_attack5_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack6_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_heavy_video_pcap_Flow.csv")
df_cic_attack6_srg['Label'] = df_cic_attack6_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack7_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_audio_pcap_Flow.csv")
df_cic_attack7_srg['Label'] = df_cic_attack7_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack8_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_compressed_pcap_Flow.csv")
df_cic_attack8_srg['Label'] = df_cic_attack8_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack9_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_exe_pcap_Flow.csv")
df_cic_attack9_srg['Label'] = df_cic_attack9_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack10_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_image.pcap_Flow.csv")
df_cic_attack10_srg['Label'] = df_cic_attack10_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack11_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_text_pcap_Flow.csv")
df_cic_attack11_srg['Label'] = df_cic_attack11_srg['Label'].map({'ManualLabel': 'Attack'})

# %%
df_cic_attack12_srg=pd.read_csv(base_dir+"csv_modified/CICBellEXFDNS2021_light_video_pcap_Flow.csv")
df_cic_attack12_srg['Label'] = df_cic_attack12_srg['Label'].map({'ManualLabel': 'Attack'})

# %% [markdown]
# ## ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import shuffle

import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
def get_score (model,x_test, y_test):
    score = model.score(x_test, y_test)
    print (f'{model}\nscore: {score}')

# %%
def evaluate_model (model,x_test,y_test):
    y_predicted = model.predict(x_test)
    cm = confusion_matrix(y_test, y_predicted)    
    print(classification_report(y_test,y_predicted))
    get_accuracy(cm)
    plt.figure(figsize=(18,12))
    sn.heatmap(cm, annot=True)
    plt.xlabel('Predicted', fontsize=24)
    plt.ylabel('Truth',fontsize=24)

# %%
def get_accuracy(cm):
    tn=cm[0][0]
    tp=cm[1][1]
    fn=cm[0][1]
    fp=cm[1][0]
    fpr=fp/(fp+tn)
    fnr=fn/(fn+tp)
    far=(fpr+fnr)/2
    acc=(tp+tn)/(tp+tn+fp+fn)
    print(f'False positive rate FPR: {fpr}\nFalse negative rate FNR: {fnr}\nFAR: {far}\nAccuracy: {acc}')

# %% [markdown]
# ## Original Evaluation

# %%
df_org=pd.concat([df_cic_normal1_org,df_cic_normal2_org,df_cic_normal3_org,df_cic_normal4_org,df_cic_normal5_org,df_cic_normal6_org,df_cic_attack1_org,df_cic_attack2_org,df_cic_attack3_org,df_cic_attack4_org,df_cic_attack5_org,df_cic_attack6_org,df_cic_attack7_org,df_cic_attack8_org,df_cic_attack9_org,df_cic_attack10_org,df_cic_attack11_org,df_cic_attack12_org],axis='index')
df_org = df_org.reset_index()

# %%
df_org=df_org.sample(frac=1).reset_index(drop=True)
#df_org = shuffle(df_org)
df_org.drop(columns=['index','Flow ID','Src IP','Src Port','Dst IP','Dst Port','Timestamp'],inplace=True)
traffic={'Normal':0,'Attack':1}
df_org.replace({'Label':traffic},inplace=True)

# %%
df_org.replace([np.inf, -np.inf], np.nan, inplace=True)
df_org=df_org.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
input = df_org.drop(columns=['Label'])
target = df_org['Label']

x_train, x_test, y_train, y_test = train_test_split(input ,target, train_size=0.7 ,random_state=2)

# %% [markdown]
# #### Random Forest Classifier

# %%
n=[100,200,300,400,500]
for it in range(len(n)):
    rt_model = RandomForestClassifier(n_estimators=n[it])
    rt_model.fit(x_train,y_train)
    get_score(rt_model,x_test,y_test)
    evaluate_model(rt_model,x_test,y_test)
# Out:
# RandomForestClassifier()
# score: 0.8312993274898387
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72     66854
#            1       0.82      0.95      0.88    123329
#
#     accuracy                           0.83    190183
#    macro avg       0.84      0.78      0.80    190183
# weighted avg       0.84      0.83      0.82    190183
#
# False positive rate FPR: 0.1378125
# False negative rate FNR: 0.17912830647827097
# FAR: 0.15847040323913547
# Accuracy: 0.8312993274898387
# RandomForestClassifier(n_estimators=200)
# score: 0.8311994237129502
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72     66854
#            1       0.82      0.95      0.88    123329
#
#     accuracy                           0.83    190183
#    macro avg       0.84      0.78      0.80    190183
# weighted avg       0.84      0.83      0.82    190183
#
# False positive rate FPR: 0.13862024500322373
# ...

# %% [markdown]
# #### SVM

# %%
svm_model = SVC()
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
import pickle

filename = 'svm1_model_cic_bell.sav'
pickle.dump(svm_model, open(filename,'wb'))

#svm1_model_bell = pickle.load(open(filename,'rb'))

# %%
#get_score(svm_model,x_test,y_test)
evaluate_model(svm_model,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.45      0.62     67110
#            1       0.77      0.99      0.87    123073
#
#     accuracy                           0.80    190183
#    macro avg       0.87      0.72      0.74    190183
# weighted avg       0.84      0.80      0.78    190183
#
# False positive rate FPR: 0.023151725914477075
# False negative rate FNR: 0.23109214652447416
# FAR: 0.12712193621947562
# Accuracy: 0.8028635577312379

# %% [markdown]
# #### AdaBoost

# %%
ab_model = AdaBoostClassifier(n_estimators=500)
ab_model.fit(x_train,y_train)
get_score(ab_model,x_test,y_test)
evaluate_model(ab_model,x_test,y_test)
# Out:
# AdaBoostClassifier(n_estimators=500)
# score: 0.8420100639909981
#               precision    recall  f1-score   support
#
#            0       0.99      0.56      0.71     66990
#            1       0.81      1.00      0.89    123193
#
#     accuracy                           0.84    190183
#    macro avg       0.90      0.78      0.80    190183
# weighted avg       0.87      0.84      0.83    190183
#
# False positive rate FPR: 0.010260625182278549
# False negative rate FNR: 0.1945351750554222
# FAR: 0.10239790011885037
# Accuracy: 0.8420100639909981

# %% [markdown]
# #### Linear Discriminant

# %%
ld_model = LinearDiscriminantAnalysis()
ld_model.fit(x_train,y_train)
get_score(ld_model,x_test,y_test)
evaluate_model(ld_model,x_test,y_test)
# Out:
# LinearDiscriminantAnalysis()
# score: 0.8410478328767556
#               precision    recall  f1-score   support
#
#            0       0.99      0.55      0.71     66854
#            1       0.80      1.00      0.89    123329
#
#     accuracy                           0.84    190183
#    macro avg       0.90      0.78      0.80    190183
# weighted avg       0.87      0.84      0.83    190183
#
# False positive rate FPR: 0.012096344452733667
# False negative rate FNR: 0.19505931831432483
# FAR: 0.10357783138352925
# Accuracy: 0.8410478328767556

# %% [markdown]
# #### KNN

# %%
n=[3,5,7,9]
for i in range(len(n)):  
  KNN_model = KNeighborsClassifier(n_neighbors=n[i])
  KNN_model.fit(x_train, y_train)
  get_score(KNN_model,x_test,y_test)
  evaluate_model(KNN_model,x_test,y_test)
# Out:
# KNeighborsClassifier(n_neighbors=3)
# score: 0.8127540316432068
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73     66854
#            1       0.85      0.87      0.86    123329
#
#     accuracy                           0.81    190183
#    macro avg       0.80      0.79      0.79    190183
# weighted avg       0.81      0.81      0.81    190183
#
# False positive rate FPR: 0.2523502274925094
# False negative rate FNR: 0.15493611530715004
# FAR: 0.20364317139982974
# Accuracy: 0.8127540316432068
# KNeighborsClassifier()
# score: 0.8162243733667047
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.72     66854
#            1       0.84      0.89      0.86    123329
#
#     accuracy                           0.82    190183
#    macro avg       0.80      0.79      0.79    190183
# weighted avg       0.81      0.82      0.81    190183
#
# False positive rate FPR: 0.2341372356205937
# ...

# %% [markdown]
# #### Logistic Regression

# %%
lr_model = LogisticRegression(max_iter=1000000)
lr_model.fit(x_train,y_train)
get_score(lr_model,x_test,y_test)
evaluate_model(lr_model,x_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(max_iter=1000000)
# score: 0.8401749893523606
#               precision    recall  f1-score   support
#
#            0       0.98      0.55      0.71     66854
#            1       0.80      1.00      0.89    123329
#
#     accuracy                           0.84    190183
#    macro avg       0.89      0.77      0.80    190183
# weighted avg       0.87      0.84      0.83    190183
#
# ...

# %% [markdown]
# #### Cross Validation

# %%
model = RandomForestClassifier(n_estimators=400)
scores=cross_val_score(model, input, target, cv=5)
print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print(scores)
# Out:
# Accuracy: 0.8328 (+/- 0.00)
# [0.83366065 0.83276152 0.83082917 0.83394328 0.83303625]

# %%
model = RandomForestClassifier(n_estimators=500)
scores=cross_val_score(model, input, target, cv=5)
print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print(scores)
# Out:
# Accuracy: 0.8329 (+/- 0.00)
# [0.83353445 0.83260377 0.83116043 0.83388018 0.83313878]

# %% [markdown]
# ## Modified Evaluation

# %%
df_srg=pd.concat([df_cic_normal1_srg,df_cic_normal2_srg,df_cic_normal3_srg,df_cic_normal4_srg,df_cic_normal5_srg,df_cic_normal6_srg,df_cic_attack1_srg,df_cic_attack2_srg,df_cic_attack3_srg,df_cic_attack4_srg,df_cic_attack5_srg,df_cic_attack6_srg,df_cic_attack7_srg,df_cic_attack8_srg,df_cic_attack9_srg,df_cic_attack10_srg,df_cic_attack11_srg,df_cic_attack12_srg],axis='index')
df_srg = df_srg.reset_index()

# %%
df_srg=df_srg.sample(frac=1).reset_index(drop=True)
#df_srg = shuffle(df_srg)
df_srg.drop(columns=['index','Flow ID','Src IP','Src Port','Dst IP','Dst Port','Timestamp'],inplace=True)
traffic={'Normal':0,'Attack':1}
df_srg.replace({'Label':traffic},inplace=True)

# %%
df_srg.replace([np.inf, -np.inf], np.nan, inplace=True)
df_srg=df_srg.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
input = df_srg.drop(columns=['Label'])
target = df_srg['Label']

x_train, x_test, y_train, y_test = train_test_split(input ,target, train_size=0.7 ,random_state=2)

# %% [markdown]
# #### Random Forest Classifier

# %%
n=[100,200,300,400,500]
for it in range(len(n)):
    rt_model = RandomForestClassifier(n_estimators=n[it])
    rt_model.fit(x_train,y_train)
    get_score(rt_model,x_test,y_test)
    evaluate_model(rt_model,x_test,y_test)
# Out:
# RandomForestClassifier()
# score: 0.8329179548657119
#               precision    recall  f1-score   support
#
#            0       0.87      0.62      0.72     66691
#            1       0.82      0.95      0.88    123497
#
#     accuracy                           0.83    190188
#    macro avg       0.84      0.78      0.80    190188
# weighted avg       0.84      0.83      0.82    190188
#
# False positive rate FPR: 0.1324842105263158
# False negative rate FNR: 0.17859946176272706
# FAR: 0.15554183614452144
# Accuracy: 0.8329179548657119
# RandomForestClassifier(n_estimators=200)
# score: 0.8331177571665931
#               precision    recall  f1-score   support
#
#            0       0.87      0.62      0.72     66691
#            1       0.82      0.95      0.88    123497
#
#     accuracy                           0.83    190188
#    macro avg       0.85      0.78      0.80    190188
# weighted avg       0.84      0.83      0.83    190188
#
# ...

# %% [markdown]
# #### SVM

# %%
svm_model = SVC()
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
import pickle

filename = 'svm2_model_cic_bell.sav'
pickle.dump(svm_model, open(filename,'wb'))

#svm1_model_bell = pickle.load(open(filename,'rb'))

# %%
#get_score(svm_model,x_test,y_test)
evaluate_model(svm_model,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.22      0.36     66952
#            1       0.70      1.00      0.82    123236
#
#     accuracy                           0.72    190188
#    macro avg       0.83      0.61      0.59    190188
# weighted avg       0.79      0.72      0.66    190188
#
# False positive rate FPR: 0.03625495419400949
# False negative rate FNR: 0.2981687328729898
# FAR: 0.16721184353349963
# Accuracy: 0.7230266893810335

# %% [markdown]
# #### AdaBoost

# %%
ab_model = AdaBoostClassifier(n_estimators=500)
ab_model.fit(x_train,y_train)
get_score(ab_model,x_test,y_test)
evaluate_model(ab_model,x_test,y_test)
# Out:
# AdaBoostClassifier(n_estimators=500)
# score: 0.8422613414095527
#               precision    recall  f1-score   support
#
#            0       0.99      0.56      0.71     66791
#            1       0.81      1.00      0.89    123397
#
#     accuracy                           0.84    190188
#    macro avg       0.90      0.78      0.80    190188
# weighted avg       0.87      0.84      0.83    190188
#
# False positive rate FPR: 0.008759046118514167
# False negative rate FNR: 0.19426349179329716
# FAR: 0.10151126895590566
# Accuracy: 0.8422613414095527

# %% [markdown]
# #### Linear Discriminant

# %%
ld_model = LinearDiscriminantAnalysis()
ld_model.fit(x_train,y_train)
get_score(ld_model,x_test,y_test)
evaluate_model(ld_model,x_test,y_test)
# Out:
# LinearDiscriminantAnalysis()
# score: 0.8416251288199045
#               precision    recall  f1-score   support
#
#            0       0.99      0.55      0.71     66691
#            1       0.80      1.00      0.89    123497
#
#     accuracy                           0.84    190188
#    macro avg       0.90      0.77      0.80    190188
# weighted avg       0.87      0.84      0.83    190188
#
# False positive rate FPR: 0.005944339367738449
# False negative rate FNR: 0.19520427215396466
# FAR: 0.10057430576085155
# Accuracy: 0.8416251288199045

# %% [markdown]
# #### KNN

# %%
n=[3,5,7,9]
for i in range(len(n)):  
  KNN_model = KNeighborsClassifier(n_neighbors=n[i])
  KNN_model.fit(x_train, y_train)
  get_score(KNN_model,x_test,y_test)
  evaluate_model(KNN_model,x_test,y_test)
# Out:
# KNeighborsClassifier(n_neighbors=3)
# score: 0.8146413022903654
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73     66691
#            1       0.84      0.88      0.86    123497
#
#     accuracy                           0.81    190188
#    macro avg       0.80      0.79      0.79    190188
# weighted avg       0.81      0.81      0.81    190188
#
# False positive rate FPR: 0.24586108775787363
# False negative rate FNR: 0.1561993517017828
# FAR: 0.2010302197298282
# Accuracy: 0.8146413022903654
# KNeighborsClassifier()
# score: 0.8169179969293541
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.72     66691
#            1       0.84      0.89      0.86    123497
#
#     accuracy                           0.82    190188
#    macro avg       0.80      0.79      0.79    190188
# weighted avg       0.81      0.82      0.81    190188
#
# False positive rate FPR: 0.2324327954732441
# ...

# %% [markdown]
# #### Logistic Regression

# %%
lr_model = LogisticRegression(max_iter=1000000)
lr_model.fit(x_train,y_train)
get_score(lr_model,x_test,y_test)
evaluate_model(lr_model,x_test,y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression(max_iter=1000000)
# score: 0.8282278587502891
#               precision    recall  f1-score   support
#
#            0       0.98      0.52      0.68     66691
#            1       0.79      0.99      0.88    123497
#
#     accuracy                           0.83    190188
#    macro avg       0.89      0.76      0.78    190188
# weighted avg       0.86      0.83      0.81    190188
#
# ...

# %% [markdown]
# #### Cross Validation

# %%
model = RandomForestClassifier(n_estimators=400)
scores=cross_val_score(model, input, target,  cv=5)
print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print(scores)
# Out:
# Accuracy: 0.8331 (+/- 0.00)
# [0.83252887 0.83253675 0.83316771 0.83405762 0.83332413]

# %%
model = RandomForestClassifier(n_estimators=500)
scores=cross_val_score(model, input, target,  cv=5)
print("Accuracy: %0.4f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print(scores)
# Out:
# Accuracy: 0.8332 (+/- 0.00)
# [0.83242634 0.83248154 0.83345952 0.83395509 0.83392354]
